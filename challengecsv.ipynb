# %%
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import shutil
import csv
import wfdb
import scipy as sp
from biosppy.signals import ecg
from wfdb import processing
from scipy import signal
import pywt
from sklearn import linear_model
from sklearn import svm
from sklearn.svm import SVC
from sklearn import decomposition
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

# %%
signals, fields = wfdb.rdsamp('Challenge/Training_WFDB/A0001')

# %%
print(signals.shape)
print(fields)
print(fields['comments'][2][4:])
# Out:
# (7500, 12)
# {'fs': 500, 'sig_len': 7500, 'n_sig': 12, 'base_date': None, 'base_time': datetime.time(0, 0, 5), 'units': ['mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV'], 'sig_name': ['I', 'II', 'III', 'aVR', 'aVL', 'aVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6'], 'comments': ['Age: 74', 'Sex: Male', 'Dx: RBBB', 'Rx: Unknown', 'Hx: Unknown', 'Sx: Unknows']}
# RBBB

# %%
record = wfdb.rdrecord('Challenge/Training_WFDB/A0001')
#annotation = wfdb.rdann('Challenge/Training_WFDB/A0001', 'atr', sampto = 1000)

wfdb.plot_wfdb( record=record,title='Record A0001 from Challenge Database',
               time_units='seconds')

# %%
sig1 = signals[0]
print (len(signals))
print(signals[0][0])
# Out:
# 7500
# 0.259

# %%
plt.plot(sig1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sig1 = []
sig2 = []
sig3 = []
sig4 = []
sig5 = []
sig6 = []
sig7 = []
sig8 = []
sig9 = []
sig10 = []
sig11 = []
sig12 = []

# %%
for i in range(0,len(signals)):
    sig1.append(float(signals[i][0]))
    sig2.append(float(signals[i][1]))
    sig3.append(float(signals[i][2]))
    sig4.append(float(signals[i][3]))
    sig5.append(float(signals[i][4]))
    sig6.append(float(signals[i][5]))
    sig7.append(float(signals[i][6]))
    sig8.append(float(signals[i][7]))
    sig9.append(float(signals[i][8]))
    sig10.append(float(signals[i][9]))
    sig11.append(float(signals[i][10]))
    sig12.append(float(signals[i][11]))

# %%
plt.plot(sig1[8000:12000])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
tsignals, tfields = wfdb.rdsamp('Challenge/Training_WFDB/A4000')
print(tsignals.shape)
print(len(tsignals))
# Out:
# (15000, 12)
# 15000
